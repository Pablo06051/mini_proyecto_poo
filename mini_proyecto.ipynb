# %%
class alumno:
    def __init__(self, cedula, nombre, edad, nota):
        self.__nombre = nombre
        self.__edad = edad 
        self.__cedula = cedula
        self.__nota = nota


    def get_nombre(self):
        return self.__nombre    
    def get_edad(self):
        return self.__edad
    def get_cedula(self):
        return self.__cedula
    def get_nota(self):
        return self.__nota
    
    def puede_votar(self):
        if self.__edad >= 18:
            print(f"{self.__nombre} puede votar.")
        else:
            print(f"{self.__nombre} NO puede votar.")

    def __str__(self):
        return f"Alumno: {self.__nombre}, Cédula: {self.__cedula}, Edad: {self.__edad}, Nota: {self.__nota}"

   
class Materia:
    def __init__(self, nombre, creditos, docente):
        self.__nombre = nombre
        self.__creditos = creditos
        self.__docente = docente
        self.__alumnos = []

    def get_nombre(self):
        return self.__nombre
    def get_creditos(self):
        return self.__creditos
    def get_docente(self):
        return self.__docente
    def set_docente(self, docente):
        self.__docente = docente

    def agregar_alumno(self, alumno):
        self.__alumnos.append(alumno)
        print(f"Alumno {alumno.get_nombre()} asignado a {self.__nombre}")

    
    def listar_alumnos(self):
        print(f"Alumnos en {self.__nombre}:")
        for alumno in self.__alumnos:
            print(f"- {alumno.get_nombre()}")

    def alumno_aprobo(self, cedula, nota_minima=6.0):
        for alumno in self.__alumnos:
            if alumno.get_cedula() == cedula:
                if alumno.get_nota() >= nota_minima:
                    print(f"El alumno {alumno.get_nombre()} APROBÓ la materia {self.__nombre}.")
                else:
                    print(f"El alumno {alumno.get_nombre()} NO aprobó la materia {self.__nombre}.")
                return
        print("Alumno no encontrado en esta materia.")


class sistemaAcademico:
    def __init__(self):
        self.__materias = []


    def agregar_materia(self, materia):
        self.__materias.append(materia)


    def listar_materias(self):
        for materia in self.__materias:
            print(materia.get_nombre())

    
    def buscar_materia(self, nombre):
        for materia in self.__materias:
            if materia.get_nombre() == nombre:
                return materia
        return None
    
    def agregar_alumno_a_materia(self, nombre_materia, alumno):
        materia = self.buscar_materia(nombre_materia)
        if materia:
            materia.agregar_alumno(alumno)
        else:
            print(f"Materia '{nombre_materia}' no encontrada.")


# Crear alumnos
alumno1 = alumno("123", "Juan", 20, 8.5)
alumno2 = alumno("456", "Ana", 17, 7.0)
alumno3 = alumno("789", "Luis", 19, 5.5)

# Crear materias
materia1 = Materia("Matemáticas", 5, "Prof. García")
materia2 = Materia("Historia", 4, "Prof. López")

# Crear sistema académico y agregar materias
sistema = sistemaAcademico()
sistema.agregar_materia(materia1)
sistema.agregar_materia(materia2)

# Asignar alumnos a materias
sistema.agregar_alumno_a_materia("Matemáticas", alumno1)
sistema.agregar_alumno_a_materia("Matemáticas", alumno2)
sistema.agregar_alumno_a_materia("Historia", alumno2)
sistema.agregar_alumno_a_materia("Historia", alumno3)

# Mostrar alumnos de cada materia
print("\n--- Alumnos por materia ---")
materia1.listar_alumnos()
materia2.listar_alumnos()

# Consultar si un alumno aprobó la materia
print("\n--- Consulta de aprobación ---")
materia1.alumno_aprobo("123")  # Juan en Matemáticas
materia2.alumno_aprobo("789")  # Luis en Historia

# Simular si pueden votar
print("\n--- Consulta si pueden votar ---")
alumno1.puede_votar()
alumno2.puede_votar()
alumno3.puede_votar()

# Mostrar resumen de alumnos por materia (toda la info)
print("\n--- Información completa de alumnos por materia ---")
def mostrar_info_alumnos(self):
    print(f"Alumnos inscritos en {self.get_nombre()}:")
    if not self._Materia__alumnos:
        print("No hay alumnos inscritos.")
    for alumno in self._Materia__alumnos:
        print(alumno)

# Puedes agregar este método a la clase Materia, pero aquí lo usamos directamente:
mostrar_info_alumnos(materia1)
mostrar_info_alumnos(materia2)
# Out:
# Alumno Juan asignado a Matemáticas
# Alumno Ana asignado a Matemáticas
# Alumno Ana asignado a Historia
# Alumno Luis asignado a Historia
#
# --- Alumnos por materia ---
# Alumnos en Matemáticas:
# - Juan
# - Ana
# Alumnos en Historia:
# - Ana
# - Luis
#
# --- Consulta de aprobación ---
# El alumno Juan APROBÓ la materia Matemáticas.
# El alumno Luis NO aprobó la materia Historia.
#
# --- Consulta si pueden votar ---
# Juan puede votar.
# Ana NO puede votar.
# Luis puede votar.
#
# --- Información completa de alumnos por materia ---
# Alumnos inscritos en Matemáticas:
# Alumno: Juan, Cédula: 123, Edad: 20, Nota: 8.5
# Alumno: Ana, Cédula: 456, Edad: 17, Nota: 7.0
# Alumnos inscritos en Historia:
# Alumno: Ana, Cédula: 456, Edad: 17, Nota: 7.0
# Alumno: Luis, Cédula: 789, Edad: 19, Nota: 5.5
